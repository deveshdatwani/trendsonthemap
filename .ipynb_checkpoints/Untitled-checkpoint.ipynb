# %%
import os
import requests
import pandas as pd
from time import sleep
import mysql.connector

#def find_current_trends():

bearer = os.environ['BEARER_TOKEN']
print('trying to connect to server')
connector = mysql.connector.connect(user='be5852720363b4', password='936fcbd3', host='us-cdbr-east-02.cleardb.com', database='heroku_4ac3cade96b682b')

if connector.is_connected():    
    cursor = connector.cursor(buffered=True)
    query = 'SELECT * FROM iterator WHERE holder = "it_holder" '
    cursor.execute(query)
    response = cursor.fetchone()
    i = response[1]
    response = response[1] + 1
    print('This is update iterator {}'.format(response))
    second_query = "UPDATE iterator SET it = {} WHERE holder = 'it_holder' ".format(response)
    cursor.execute(second_query)
    connector.commit()
    third_query = 'SELECT * FROM trendsincities'
    third_response = cursor.execute(third_query)
    response = cursor.fetchall()
    print('iterator token accessed and updated. Fetched trendingcities')
    print(i)

split_end = i * 5
split_start = split_end - 5

trends = [x[6] for x in response]
woeids = [x[3] for x in response] 
#print(woeids)
woeids = woeids[split_start:split_end]
trends_in_woeids = []
url = 'https://api.twitter.com/1.1/trends/place.json'
l2 = []

for woeid in woeids:
    param = {'id' : woeid}
    response = requests.get(url = url, headers = {'authorization': 'Bearer ' + bearer}, params = param).json()
    l1 = []
    #print(response)
    for i in response[0]['trends']:
        l1.append(i['name'])
    l2.append(l1)

print('All trends acquired')

trends[split_start:split_end] = l2
for num, i in enumerate(trends):
    if type(i) == list:
         trends[num] = ' '.join(i)
#print(trends)
connector = mysql.connector.connect(user='be5852720363b4', password='936fcbd3', host='us-cdbr-east-02.cleardb.com', database='heroku_4ac3cade96b682b')
cursor = connector.cursor(buffered=True)
#values = ','.join(trends)
#values = tuple(values)
fourth_query = 'UPDATE trendsincities SET trends = (%s)'
cursor.executemany(fourth_query, trends)
connector.commit()
#rint(cursor._last_executed)
print('Done')
cursor.close()
connector.close()

#find_current_trends()
# Out:
# trying to connect to server
# This is update iterator 43
# iterator token accessed and updated. Fetched trendingcities
# 42
# All trends acquired
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-faa79d170150> in <module>
#      54 connector = mysql.connector.connect(user='be5852720363b4', password='936fcbd3', host='us-cdbr-east-02.cleardb.com', database='heroku_4ac3cade96b682b')
#      55 cursor = connector.cursor(buffered=True)
# ---> 56 values = ','.join(trends)
#      57 #values = tuple(values)
#      58 fourth_query = 'UPDATE trendsincities SET trends = (%s)'
#
# TypeError: sequence item 205: expected str instance, list found

# %%
for num, i in enumerate(trends):
    if type(i) == list:
         trends[num] = ' '.join(i)

# %%
trends
# Out:
# ['Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'الزمالك #DCFanDome الاهلي #منذر_المزكي Ganesh Chaturthi #ENGvPAK #dynamitebts Lucifer #محمود_عباس sevilla اشبيلية Lucy مروان conte Egyptian maguire batman كونتي zak crawley تويتر Chilwell niki chloe disney السيسي cuties Germany seokjin Karachi armys sooo Travis scott heather #ArrestMarviSirmed_295C #غول_الموت #PakvsEng #نلتزم_لننتصر #Dynamite100M #askdxbofficial #اشبيليه #mayward #ليبيا #DynamiteMV #GaneshChaturthi2020 #libya #انتر_ميلان #ipl2020 #islamicnewyear #china #cricket',
#  'الزمالك #DCFanDome الاهلي #منذر_المزكي Ganesh Chaturthi #ENGvPAK #dynamitebts Lucifer #محمود_عباس sevilla اشبيلية Lucy مروان conte Egyptian maguire batman كونتي zak crawley تويتر Chilwell niki chloe disney السيسي cuties Germany seokjin Karachi armys sooo Travis scott heather #ArrestMarviSirmed_295C #غول_الموت #PakvsEng #نلتزم_لننتصر #Dynamite100M #askdxbofficial #اشبيليه #mayward #ليبيا #DynamiteMV #GaneshChaturthi2020 #libya #انتر_ميلان #ipl2020 #islamicnewyear #china #cricket',
#  'الزمالك #DCFanDome الاهلي #منذر_المزكي Ganesh Chaturthi #ENGvPAK #dynamitebts Lucifer #محمود_عباس sevilla اشبيلية Lucy مروان conte Egyptian maguire batman كونتي zak crawley تويتر Chilwell niki chloe disney السيسي cuties Germany seokjin Karachi armys sooo Travis scott heather #ArrestMarviSirmed_295C #غول_الموت #PakvsEng #نلتزم_لننتصر #Dynamite100M #askdxbofficial #اشبيليه #mayward #ليبيا #DynamiteMV #GaneshChaturthi2020 #libya #انتر_ميلان #ipl2020 #islamicnewyear #china #cricket',
#  'שבוע טוב שבת שלום #DCFanDome #DynamiteBTS גיא פלג Pompeo google shabbat shalom #master European #luciferseason5 #BTS_Dynamite sderot צבע אדום כי היא Michael Putin כרמי גילון holocaust Hamas יאיר נתניהו beirut טוב נו arsenal Taylor biden Pakistan נו באמת אהוד ברק Quinn Check Out עד עכשיו jesus Eilat יום אחד jungkook new york TikTok Holy palestine בן אדם אחר כך Republican כך יפה nazi #Gaza #ביביתתפטר #odedfriedgaon #OdedMusic #Netanyahu',
#  'שבוע טוב שבת שלום #DCFanDome #DynamiteBTS גיא פלג Pompeo google shabbat shalom #master European #luciferseason5 #BTS_Dynamite sderot צבע אדום כי היא Michael Putin כרמי גילון holocaust Hamas Egypt יאיר נתניהו beirut טוב נו arsenal Taylor biden Pakistan נו באמת אהוד ברק Quinn Check Out עד עכשיו jesus Eilat יום אחד jungkook new york TikTok Holy palestine בן אדם אחר כך Republican כך יפה #Gaza #ביביתתפטר #odedfriedgaon #OdedMusic #Netanyahu',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available',
#  'Trends not available']
